# %% [markdown]
# Model Integration with OpenAI, Gemini and Groq

# %%
import os 
from dotenv import load_dotenv 
load_dotenv()

# os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite"
)
response = model.invoke("Why do parrots talk?")
print(response.content)

# %% [markdown]
# GROQ Model Integration

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant"    
)

response = llm.invoke("Did you know Andhra")
print(response.content)
# Out:
# It seems like you're about to ask a question, but it got cut off. You said "Did you know Andhra." Are you referring to the state of Andhra Pradesh in India? Or perhaps you're asking about something else related to "Andhra"? If you could provide more context or complete your question, I'd be happy to help.

# %% [markdown]
# Streming and Batch

# %%
model.invoke("Explain about strem and batch")
# Out:
# AIMessage(content='The terms "stream" and "batch" refer to two fundamental ways of processing data, each with its own characteristics, use cases, and trade-offs. Understanding the difference is crucial for designing efficient and effective data pipelines and applications.\n\nLet\'s break them down:\n\n## Stream Processing\n\n**Concept:** Stream processing deals with data that is generated continuously and in real-time. Think of it as an unending flow of data, where events arrive one after another. The goal is to process these events as they arrive, often with very low latency.\n\n**Key Characteristics:**\n\n*   **Continuous Flow:** Data is not collected and stored in a large chunk before processing. It\'s processed as it\'s generated.\n*   **Low Latency:** The primary objective is to react to data as quickly as possible, often within milliseconds or seconds.\n*   **Infinite Data:** Conceptually, a data stream is infinite. You\'re not processing a "complete" dataset.\n*   **Event-Driven:** Processing is triggered by the arrival of individual events or small groups of events.\n*   **Stateful Processing:** Often, stream processing requires maintaining some state to make decisions. For example, tracking a user\'s session or aggregating metrics over a time window.\n*   **Unbounded Data:** The dataset is not finite and has no predefined end.\n\n**Analogy:** Imagine a river. Water flows continuously. You can dip your hand in to feel the temperature, or you can have a water wheel that generates power as the water flows by. You\'re not waiting for the entire river to be collected before you can interact with it.\n\n**Common Use Cases:**\n\n*   **Real-time Analytics:** Monitoring website traffic, social media feeds, sensor data.\n*   **Fraud Detection:** Identifying suspicious transactions as they occur.\n*   **IoT Data Processing:** Analyzing data from connected devices (e.g., smart home sensors, industrial machinery).\n*   **Log Monitoring and Alerting:** Detecting errors or anomalies in system logs in real-time.\n*   **Personalization:** Recommending products or content to users based on their immediate actions.\n*   **Algorithmic Trading:** Executing trades based on market fluctuations in milliseconds.\n\n**Technologies:**\n\n*   Apache Kafka\n*   Apache Flink\n*   Apache Spark Streaming / Structured Streaming\n*   Amazon Kinesis\n*   Google Cloud Dataflow\n*   RabbitMQ (can be used for message queuing in streaming architectures)\n\n## Batch Processing\n\n**Concept:** Batch processing deals with data that is collected and stored over a period of time and then processed in discrete chunks or "batches." The focus is on processing large volumes of data efficiently, often for historical analysis or reporting.\n\n**Key Characteristics:**\n\n*   **Discrete Batches:** Data is accumulated and processed in defined intervals (e.g., hourly, daily, weekly).\n*   **High Latency (relatively):** There\'s a delay between when data is generated and when it\'s processed. This latency is acceptable because the goal is not immediate reaction.\n*   **Finite Data:** You are processing a complete, bounded dataset.\n*   **Scheduled or Triggered:** Batch jobs are typically scheduled to run at specific times or triggered by certain events (e.g., end of day).\n*   **Stateless (often):** While some batch processing can involve state, many operations are stateless, meaning each record is processed independently without relying on previous records within the same batch.\n*   **Bounded Data:** The dataset has a clear beginning and end.\n\n**Analogy:** Imagine collecting all the mail delivered to your house for a week. You then sort through it all at once to pay bills, respond to letters, and discard junk mail. You\'re not dealing with each letter the moment it arrives; you\'re processing a collection of them.\n\n**Common Use Cases:**\n\n*   **Data Warehousing:** Loading and transforming large datasets for historical analysis and business intelligence.\n*   **Repo ...

# %%
for chunk in model.stream("What is capital of Andhrapradesh"):
    print(chunk.text, end="|", flush=True)
# Out:
# The capital of Andhra Pradesh is
#  **Amaravati**.

# %% [markdown]
# BATCH

# %%
responses = model.batch({[
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "what is quantum computing?"
]})
for response in responses:
    print(response)

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "what is quantum computing?"
],
config={
    'max_concurrency': 5, # Limit to 5 parallel calls 
    }
)
for response in responses:
    print(response)
