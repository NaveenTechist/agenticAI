# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="llama-3.1-8b-instant")

messages = [
    (
        "system", "Your a helpful assistant that give a short answer to a question"
    ),
    (
        "human", "how many moons does have in Jupiter?"
    )
]

response=llm.invoke(messages)
print(response)
print(response.content)
# Out:
# content='Jupiter has a total of 92 confirmed moons.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 55, 'total_tokens': 67, 'completion_time': 0.012490459, 'completion_tokens_details': None, 'prompt_time': 0.002681636, 'prompt_tokens_details': None, 'queue_time': 0.045175194, 'total_time': 0.015172095}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ec9ad-4581-7883-9fc3-7ea766d69545-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 55, 'output_tokens': 12, 'total_tokens': 67}
# Jupiter has a total of 92 confirmed moons.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

print(llm.invoke("Say hello"))
# Out:
# content='Hello! How can I help you today?' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019eca1d-b8cd-71d1-8876-11d430d9e284-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 3, 'output_tokens': 9, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}}
