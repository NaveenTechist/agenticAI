# %% [markdown]
# # Middleware

# %% [markdown]
# Middleware can control what happend inside the agent. Middleware is useful following
#
# 1. Tracking agent behaviour with logging, anylytics and debugging
# 2. Transforming prompts, tool selection, output formating
# 3. Rate limits, Guardrils, PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# # Summarization Middleware
#
# Automatically summarize conversation history when token limts out.
